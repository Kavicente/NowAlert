# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import joblib

# %%
df = pd.read_csv('road_accident.csv')
df.columns = [c.strip() for c in df.columns]

# %%
df.head()
# Out:
#          Date  Year   Time Day_of_Week               Barangay   Latitude  \
# 0  04/08/2021  2021  21:15   Wednesday     I-C (Bagong Bayan)  14.071215
# 1  20/08/2021  2021   7:15      Friday   Santa Veronica (Bae)  14.080453
# 2  05/09/2023  2023   3:32     Tuesday           I-A (Sambat)  14.080712
# 3  14/12/2021  2021  15:08     Tuesday        VI-A (Mavenida)  14.047567
# 4  05/02/2020  2020  13:01   Wednesday  San Lucas 2 (Malinaw)  14.080015
#
#     Longitude Weather Road_Condition Vehicle_Type  Driver_Age Driver_Gender  \
# 0  121.322198   Sunny            Dry   Motorcycle          44          Male
# 1  121.330692   Sunny            Dry      Bicycle          38          Male
# 2  121.301354   Rainy            Wet          Car          29        Female
# 3  121.298669   Rainy            Wet   Motorcycle          50          Male
# 4  121.329899   Rainy            Wet   Motorcycle          27          Male
#
#           Accident_Cause Road_Accident_Type  Injuries  Fatalities
# 0      Head-on collision      Drunk Driving         4           0
# 1     Rear-end collision      Drunk Driving         1           1
# 2  Side-impact collision   Reckless Driving         2           0
# 3  Side-impact collision        Overloading         5           0
# 4      Head-on collision            Fatigue         2           0

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Time', 'Day_of_Week', 'Barangay', 'Latitude',
#        'Longitude', 'Weather', 'Road_Condition', 'Vehicle_Type', 'Driver_Age',
#        'Driver_Gender', 'Accident_Cause', 'Road_Accident_Type', 'Injuries',
#        'Fatalities'],
#       dtype='object')

# %%
df.shape
# Out:
# (1500, 16)

# %%
date_col = next((c for c in df.columns if 'date' in c.lower()), None)
accident_cause_col = next((c for c in df.columns if 'accident' in c.lower() and 'cause' in c.lower()), None)
accident_type_col = next((c for c in df.columns if 'road' in c.lower() and 'type' in c.lower()), None)
if not accident_type_col:
    accident_type_col = next((c for c in df.columns if 'accident_type' in c.lower() or 'accident type' in c.lower()), None)
barangay_col = next((c for c in df.columns if 'barangay' in c.lower()), None)

if date_col is None:
    raise ValueError("No date column detected. Please ensure your CSV contains a Date column.")

# %%
X = df[['Year', 'Barangay', 'Road_Accident_Type', 'Accident_Cause']]
y = df['Fatalities'].apply(lambda x: 1 if x > 0 else 0)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['Year']),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), ['Barangay', 'Road_Accident_Type', 'Accident_Cause'])
    ]
)

# %%
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression())
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Year']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Barangay',
#                                                    'Road_Accident_Type',
#                                                    'Accident_Cause'])])),
#                 ('classifier', LogisticRegression())])

# %%
y_pred = pipe.predict(X_test)
print("=== Logistic Regression - Classification Report ===")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# === Logistic Regression - Classification Report ===
#               precision    recall  f1-score   support
#
#            0     0.7981    0.9663    0.8742       356
#            1     0.3684    0.0745    0.1239        94
#
#     accuracy                         0.7800       450
#    macro avg     0.5833    0.5204    0.4990       450
# weighted avg     0.7084    0.7800    0.7175       450

# %%
# === Classification Report ===
cm = confusion_matrix(y_test, y_pred)
print("=== Logistic Regression - Confusion Matrix ===")
print(cm)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title("Logistic Regression - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# === Logistic Regression - Confusion Matrix ===
# [[344  12]
#  [ 87   7]]

# %%
if hasattr(pipe, "predict_proba"):
    y_proba = pipe.predict_proba(X_test)[:,1]
else:
    # fallback (should not happen for LR)
    y_proba = pipe.decision_function(X_test)
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)
print(f"=== Logistic Regression - ROC AUC: {roc_auc:.4f} ===")
plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1],[0,1],'--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Logistic Regression - ROC Curve")
plt.legend(loc='lower right')
plt.show()
# Out:
# === Logistic Regression - ROC AUC: 0.6875 ===

# %%
joblib.dump(pipe, "road_predictor_lr.pkl")
print("Saved model to road_predictor_lr.pkl")
# Out:
# Saved model to road_predictor_lr.pkl

# %% [markdown]
# After the installation is complete, please run the cell with the error again.

# %% [markdown]
# # Task
# Train a Logistic Regression model to predict the occurrence of road accidents based on features like 'Road_Accident_Type' and 'Accident_Cause' using the dataset "Road_Accident_Data.csv".

# %% [markdown]
# ## Data preparation
#
# ### Subtask:
# Define the features (excluding 'Fatalities' and the non-predictive columns like 'Date' and 'Time') and the target variable (whether an accident occurred, which can be inferred from the dataset having entries only for accidents). Create a new binary target variable indicating the occurrence of an accident.

# %% [markdown]
# **Reasoning**:
# Create the feature DataFrame by dropping the specified columns and create the binary target variable indicating accident occurrence.
